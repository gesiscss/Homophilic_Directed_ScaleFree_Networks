# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2019, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %% [markdown]
# <div style="text-align:center;"><h1>Vertical Inequality on Real-world networks</h1></div>

# %% [markdown]
# <h2>Dependencies</h2>

# %%
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import os
import sys

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.append('../../code')

from org.gesis.libs import io
from org.gesis.libs import viz
from org.gesis.libs.utils import printf
from org.gesis.libs.network import load_all_datasets_node_metadata_fit

# %% [markdown]
# <h2>Constants</h2>

# %%
DATASETS = ['aps', 'apsgender3', 'apsgender8', 'github','pokec','wikipedia'] #'twitter'
MODELS = ['DHBA'] #['DBA', 'DH', 'DHBA']
ROOT = '../../data/'
PLOTS = '../../plots/'
OUTPUT = "../../results-batch/"

# %% [markdown]
# <h2>Loading metadata distributions</h2>

# %%
df_metadata = load_all_datasets_node_metadata_fit(DATASETS, MODELS, OUTPUT)

# %%
df_metadata.sample(5)
# Out:
#           dataset  node  minority  indegree  outdegree  pagerank  \
# 14220         aps   220         0         1          1  0.000136
# 50151  apsgender8   151         0         8          4  0.001021
# 35523  apsgender3  1523         0         5          1  0.000219
# 56730  apsgender8   730         0         9         10  0.000959
# 58026  apsgender8    26         0         2          1  0.000186
#
#        circle_of_trust  wtf model  epoch
# 14220                1    1  DHBA      5
# 50151               11   19  DHBA      6
# 35523                0    1  DHBA      5
# 56730               10    9  DHBA      5
# 58026                1    0  DHBA      9

# %% [markdown]
# <h2>In-degree distribution</h2>

# %%
metric = 'indegree'

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', fn=fn)
# Out:
# ../../plots/indegree_fit_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, groups=True, row='model', fn=fn)
# Out:
# ../../plots/indegree_fit_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Out-degree distribution</h2>

# %%
metric = 'outdegree'

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', fn=fn)
# Out:
# ../../plots/outdegree_fit_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', groups=True, fn=fn)
# Out:
# ../../plots/outdegree_fit_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>PageRank distribution</h2>

# %%
metric = 'pagerank'

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', fn=fn)
# Out:
# ../../plots/pagerank_fit_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', groups=True, fn=fn)
# Out:
# ../../plots/pagerank_fit_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Circle of Trust distribution</h2>

# %%
metric = 'circle_of_trust'

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', fn=fn)
# Out:
# ../../plots/circle_of_trust_fit_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', groups=True, fn=fn)
# Out:
# ../../plots/circle_of_trust_fit_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Whom-To-Follow Twitter</h2>

# %%
metric = 'wtf'

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', fn=fn)
# Out:
# ../../plots/wtf_fit_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_fit_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, row='model', groups=True, fn=fn)
# Out:
# ../../plots/wtf_fit_vertical_inequality_per_group.pdf saved!
