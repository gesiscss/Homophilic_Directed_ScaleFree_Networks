# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2019, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %% [markdown]
# <div style="text-align:center;"><h1>Vertical Inequality on Real-world networks</h1></div>

# %% [markdown]
# <h2>Dependencies</h2>

# %%
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import os
import sys

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.append('../../code')

from org.gesis.libs import io
from org.gesis.libs import viz
from org.gesis.libs.utils import printf
from org.gesis.libs.network import load_all_node_metadata_synthetic

# %% [markdown]
# <h2>Constants</h2>

# %%
MODEL = 'DHBA'
ROOT = '../../data/'
PLOTS = '../../plots/'
OUTPUT = "../../results-batch/"

# %% [markdown]
# <h2>Loading metadata distributions</h2>

# %%
df_metadata = load_all_node_metadata_synthetic(MODEL, OUTPUT)
# Out:
# 2020-03-06 23:44:08	../../results-batch/synthetic/DHBA_all_metadata.csv saved!

# %%
df_metadata.sample(5)
# Out:
#          node  minority  indegree  outdegree  pagerank  circle_of_trust  wtf  \
# 1563941  1941         0         0          2  0.000075                0    0
# 1593563  1563         0         0          2  0.000075                0    0
# 879595   1595         0         0          2  0.000075                0    0
# 1135811  1811         0         0          2  0.000109                0    0
# 1694986   986         0         1          2  0.000107                1    0
#
#             N  kmin   fm  hMM  hmm   gm   gM  epoch
# 1563941  2000     2  0.1  0.8  0.0  2.5  2.5      1
# 1593563  2000     2  0.1  0.3  0.3  2.5  2.5      8
# 879595   2000     2  0.3  0.2  0.0  2.5  2.5      7
# 1135811  2000     2  0.3  1.0  0.8  2.5  2.5      7
# 1694986  2000     2  0.5  0.3  0.3  2.5  2.5      8

# %%
df_metadata_sym = df_metadata.query("hmm==hMM").copy()
hs = [0.0, 0.2, 0.5, 0.8, 1.0]
df_metadata_asym = df_metadata.query("hmm in @hs and hMM in @hs").copy()

# %% [markdown]
# <h1>Symmetric Homophily</h1>

# %% [markdown]
# <h2>In-degree distribution</h2>

# %%
metric = 'indegree'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/indegree_synthetic_vertical_inequality_symmetric_homophily.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, groups=True, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/indegree_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf saved!

# %% [markdown]
# <h2>Out-degree distribution</h2>

# %%
metric = 'outdegree'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/outdegree_synthetic_vertical_inequality_symmetric_homophily.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, groups=True, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/outdegree_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf saved!

# %% [markdown]
# <h2>PageRank distribution</h2>

# %%
metric = 'pagerank'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/pagerank_synthetic_vertical_inequality_symmetric_homophily.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, groups=True, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/pagerank_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf saved!

# %% [markdown]
# <h2>Circle of Trust distribution</h2>

# %%
metric = 'circle_of_trust'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/circle_of_trust_synthetic_vertical_inequality_symmetric_homophily.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, groups=True, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/circle_of_trust_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf saved!

# %% [markdown]
# <h2>Whom-To-Follow Twitter</h2>

# %%
metric = 'wtf'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/wtf_synthetic_vertical_inequality_symmetric_homophily.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_sym, metric, groups=True, col='hmm', row='fm', fn=fn)
# Out:
# ../../plots/wtf_synthetic_vertical_inequality_symmetric_homophily_per_group.pdf saved!

# %% [markdown]
# <h1>Assymetric Homophily</h1>

# %%
metric = 'wtf'

# %%
fn = os.path.join(PLOTS, '{}_synthetic_vertical_inequality_asymmetric_homophily.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata_asym.query("fm==0.5"), metric, col='hmm', row='hMM', fn=fn)
