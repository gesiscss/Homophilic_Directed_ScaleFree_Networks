# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2019, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %% [markdown]
# <div style="text-align:center;"><h1>Vertical Inequality on Real-world networks</h1></div>

# %% [markdown]
# <h2>Dependencies</h2>

# %%
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import os
import sys

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.append('../../code')

from org.gesis.libs import io
from org.gesis.libs import viz
from org.gesis.libs.utils import printf
from org.gesis.libs.network import load_all_node_metadata_empirical

# %% [markdown]
# <h2>Constants</h2>

# %%
DATASETS = ['aps', 'apsgender3', 'apsgender8', 'github', 'pokec', 'wikipedia'] #'twitter'
ROOT = '../../data/'
PLOTS = '../../plots/'
OUTPUT = "../../results-batch/"

# %% [markdown]
# <h2>Loading metadata distributions</h2>

# %%
df_metadata = load_all_node_metadata_empirical(DATASETS, ROOT)
# Out:
# 2020-03-06 15:07:35	=== aps ===
# 2020-03-06 15:07:35	loaded!
# 2020-03-06 15:07:35	=== apsgender3 ===
# 2020-03-06 15:07:35	loaded!
# 2020-03-06 15:07:35	=== apsgender8 ===
# 2020-03-06 15:07:35	loaded!
# 2020-03-06 15:07:35	=== github ===
# 2020-03-06 15:07:35	loaded!
# 2020-03-06 15:07:35	=== pokec ===
# 2020-03-06 15:07:36	loaded!
# 2020-03-06 15:07:37	=== wikipedia ===
# 2020-03-06 15:07:37	loaded!
# 2020-03-06 15:07:54	../../data/all_datasets_empirical_metadata.csv saved!

# %%
df_metadata.sample(5)
# Out:
#             node  minority  indegree  outdegree      pagerank  \
# 213955    202329         0         1          1  2.217566e-06
# 398435     80233         1        22         38  6.351984e-07
# 1389802  1071602         1         1          0  1.256172e-07
# 950536    632334         0         2          1  1.610633e-07
# 318460       258         0         3          7  1.843515e-07
#
#          circle_of_trust   wtf dataset
# 213955               0.0  33.0  github
# 398435               NaN   NaN   pokec
# 1389802              NaN   NaN   pokec
# 950536               NaN   NaN   pokec
# 318460               NaN   NaN   pokec

# %% [markdown]
# <h2>In-degree distribution</h2>

# %%
tmp = df_metadata.copy()
tmp.drop(columns=['circle_of_trust',"wtf"], inplace=True)

# %%
metric = 'indegree'

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, fn=fn)
# Out:
# ../../plots/indegree_empirical_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, groups=True, fn=fn)
# Out:
# ../../plots/indegree_empirical_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Out-degree distribution</h2>

# %%
metric = 'outdegree'

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, fn=fn)
# Out:
# ../../plots/outdegree_empirical_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, groups=True, fn=fn)
# Out:
# ../../plots/outdegree_empirical_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>PageRank distribution</h2>

# %%
metric = 'pagerank'

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, fn=fn)
# Out:
# ../../plots/pagerank_empirical_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(tmp, metric, groups=True, fn=fn)
# Out:
# ../../plots/pagerank_empirical_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Circle of Trust distribution</h2>

# %%
metric = 'circle_of_trust'

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, fn=fn)
# Out:
# ../../plots/circle_of_trust_empirical_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, groups=True, fn=fn)
# Out:
# ../../plots/circle_of_trust_empirical_vertical_inequality_per_group.pdf saved!

# %% [markdown]
# <h2>Whom-To-Follow Twitter</h2>

# %%
metric = 'wtf'

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, fn=fn)
# Out:
# ../../plots/wtf_empirical_vertical_inequality.pdf saved!

# %%
fn = os.path.join(PLOTS, '{}_empirical_vertical_inequality_per_group.pdf'.format(metric))
viz.plot_lorenz_curve(df_metadata, metric, groups=True, fn=fn)
# Out:
# ../../plots/wtf_empirical_vertical_inequality_per_group.pdf saved!
