# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2019, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %% [markdown]
# <div style="text-align:center;"><h1>Generating a new Directed Network</h1></div>

# %% [markdown]
# <h2>Dependencies</h2>

# %%
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.append('../../code')
from org.gesis.model import graph
from org.gesis.model.graph import DirectedGraph
from org.gesis.libs import viz

# %% [markdown]
# <h2>Parameters</h2>

# %%
kind = graph.kDHBA           # kind: kDBA, kDH, kT, kHDBA, kHTDBA
N = 20                       # number of nodes
kmin = 2                     # minimum degree
density = 0.005              # edge density
minority_fraction = 0.3      # minority fraction
gamma_m = 3                  # exponent degree power-law minority 
gamma_M = 3                  # exponent degree power-law majority
h_mm = 1.0                   # homophily between minorities
h_MM = 1.0                   # homophily between majorities
triads_ratio = None          # triads density
triads_pdf = [1/12]*12       # pdf for 12 triads: [mmm, mnm, MMM, MNM, mmN, mmM, mMn, nMm, nMM, mMM, mNM, mMN]

# %% [markdown]
# <h2>Network generation</h2>

# %%
DG = DirectedGraph(kind,
                   N=N,
                   kmin=kmin,
                   density=density,
                   minority_fraction=minority_fraction,
                   gamma_m=gamma_m,
                   gamma_M=gamma_M,
                   h_mm=h_mm,
                   h_MM=h_MM,
                   triads_ratio=triads_ratio,
                   triads_pdf=triads_pdf)
DG.create_network()
DG.info()
# Out:
# density: 0.005
# EXPECTED_E: 2
# ADD_NEW_EDGES (y): 1
# START (x): 0
#
# 0 times, an edge was not inserted
#
# Name: DHBA
# Type: DiGraph
# Number of nodes: 20
# Number of edges: 36
# Average in degree:   1.8000
# Average out degree:   1.8000
# {'class': 'color', 'gamma_M': 3, 'name': 'DHBA', 'labels': ['blue', 'red'], 'N': 20, 'label': 'minority', 'gamma_m': 3, 'h_mm': 1.0, 'density': 0.005, 'seed': None, 'fm': 0.3, 'minority': 'red', 'h_MM': 1.0, 'kmin': 2, 'groups': ['M', 'm']}
#
# created in 0.012779712677001953 seconds.

# %% [markdown]
# <h2>Plots</h2>

# %%
viz.plot_simple_network(DG.G)
