# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2019, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %% [markdown]
# <div style="text-align:center;"><h1>Generating a new Directed Network</h1></div>

# %% [markdown]
# <h2>Dependencies</h2>

# %%
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.append('../../code')
from org.gesis.model import graph
from org.gesis.model.graph import DirectedGraph
from org.gesis.libs import viz

# %% [markdown]
# <h2>Parameters</h2>

# %%
kind = graph.kDH             # kind: kDBA, kDH, kT, kHDBA, kHTDBA
N = 100                      # number of nodes
kmin = 1                     # minimum degree
density = 0.01               # edge density
minority_fraction = 0.1      # minority fraction
gamma_m = 3                  # exponent degree power-law minority 
gamma_M = 3                  # exponent degree power-law majority
h_mm = 1.0                   # homophily between minorities
h_MM = 1.0                   # homophily between majorities
triads_ratio = None          # triads density
triads_pdf = [1/12]*12       # pdf for 12 triads: [mmm, mnm, MMM, MNM, mmN, mmM, mMn, nMm, nMM, mMM, mNM, mMN]

# %% [markdown]
# <h2>Network generation</h2>

# %%
DG = DirectedGraph(kind,
                   N=N,
                   kmin=kmin,
                   density=density,
                   minority_fraction=minority_fraction,
                   gamma_m=gamma_m,
                   gamma_M=gamma_M,
                   h_mm=h_mm,
                   h_MM=h_MM,
                   triads_ratio=triads_ratio,
                   triads_pdf=triads_pdf)
DG.create_network()
DG.info()
# Out:
# density: 0.01
# EXPECTED_E: 99
# ADD_NEW_EDGES (y): 1
# START (x): 1
#
# 10 times, an edge was not inserted
#
# Name: DH
# Type: DiGraph
# Number of nodes: 100
# Number of edges: 148
# Average in degree:   1.4800
# Average out degree:   1.4800
# {'seed': None, 'h_MM': 1.0, 'class': 'color', 'density': 0.01, 'h_mm': 1.0, 'gamma_m': 3, 'N': 100, 'label': 'minority', 'gamma_M': 3, 'kmin': 1, 'groups': ['M', 'm'], 'minority': 'red', 'fm': 0.1, 'name': 'DH', 'labels': ['blue', 'red']}
#
# created in 0.06330013275146484 seconds.

# %% [markdown]
# <h2>Plots</h2>

# %%
viz.plot_simple_network(DG.G)
